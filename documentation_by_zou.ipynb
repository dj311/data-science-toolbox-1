# %% [markdown]
# # Time Series analysis of HTTP Bro Log

# %%
# %matplotlib notebook
import pandas as pd

# %% [markdown]
# ## Data input

# %%
http_df = pd.read_csv("resources/Virusshare.csv", header=None)
http_df.head()
# Out:
#                                                  0                 1   \
# 0                                          FileName  SectionAlignment
# 1  VirusShare_001dd76872d80801692ff942308c64e6.json              4096
# 2  VirusShare_002325a0a67fded0381b5648d7fe9b8e.json              4096
# 3  VirusShare_00dbb9e1c09dbdafb360f3163ba5a3de.json               512
# 4  VirusShare_0149b7bd7218aab4e257d28469fddb0d.json              4096
#
#               2              3                                          4   \
# 0  FileAlignment  SizeOfHeaders                              TimeDateStamp
# 1            512           1024  0x4CCFCD6C [Tue Nov  2 08:35:56 2010 UTC]
# 2            512           1024  0x4CD24D8F [Thu Nov  4 06:07:11 2010 UTC]
# 3            512           1024  0x5022F5F9 [Wed Aug  8 23:27:53 2012 UTC]
# 4            512           1024  0x4DE35569 [Mon May 30 08:29:29 2011 UTC]
#
#           5            6                   7                8            9   \
# 0  ImageBase  SizeOfImage  DllCharacteristics  Characteristics  HighEntropy
# 1    4194304        77824                   0              271            0
# 2    4194304        81920                   0              271            0
# 3    4194304        65024                   0              271            0
# 4    4194304      2035712                   0              271            0
#
#            10                       11                          12
# 0  LowEntropy  TotalSuspiciousSections  TotalNonSuspiciousSections
# 1           0                        0                           3
# 2           0                        0                           4
# 3           1                        1                           1
# 4           0                        0                           4

# %% [markdown]
# ## Timestamp

# %%
#clean up the timestamp column ts
from datetime import datetime
http_df['ts'] = [datetime.fromtimestamp(float(date)) for date in http_df['ts'].values]
http_df = http_df.set_index('ts')
http_df.head()
# code provided by https://github.com/sooshie/Security-Data-Analysis/blob/master/Lab_2/Lab_2-Solutions.ipynb
# Out:
#                                            uid      id.orig_h  id.orig_p  \
# ts
# 2012-05-31 01:09:27.177343  ChBJ7L2l1Vcl8PmMxh  192.168.88.10       1030
# 2012-05-31 01:09:28.343725  CKH7Eu1pUtdXF8KKq8  192.168.88.10       1031
# 2012-05-31 01:09:29.124170  CMjfL821GNMgnPFTa9  192.168.88.10       1034
# 2012-05-31 01:09:29.142869  Ckt4Bw4pZVSaU17gSg  192.168.88.10       1035
# 2012-05-31 01:09:29.602005  ChBJ7L2l1Vcl8PmMxh  192.168.88.10       1030
#
#                                  id.resp_h  id.resp_p  trans_depth method  \
# ts
# 2012-05-31 01:09:27.177343  188.121.46.128         80            1    GET
# 2012-05-31 01:09:28.343725    50.28.53.156         80            1    GET
# 2012-05-31 01:09:29.124170  188.72.248.160         80            1    GET
# 2012-05-31 01:09:29.142869    69.63.148.95         80            1    GET
# 2012-05-31 01:09:29.602005  188.121.46.128         80            2    GET
#
#                                                host  \
# ts
# 2012-05-31 01:09:27.177343               myfecm.com
# 2012-05-31 01:09:28.343725       www.daysofyorr.com
# 2012-05-31 01:09:29.124170            potialosce.tk
# 2012-05-31 01:09:29.142869  www.12secondcommute.com
# 2012-05-31 01:09:29.602005               myfecm.com
#
#                                                   uri            referrer  \
# ts
# 2012-05-31 01:09:27.177343                          /                   -
# 2012-05-31 01:09:28.343725                /release.js  http://myfecm.com/
# 2012-05-31 01:09:29.124170             /25433658.html  http://myfecm.com/
# 2012-05-31 01:09:29.142869  /common/formValidation.js  http://myfecm.com/
# 2012-05-31 01:09:29.602005            /button_bg6.jpg  http://myfecm.com/
#
#                             ...   filename     tags  username password  \
# ts                          ...
# 2012-05-31 01:09:27.177343  ...          -  (empty)         -        -
# 2012-05-31 01:09:28.343725  ...          -  (empty)         -        -
# 2012-05-31 01:09:29.124170  ...          -  (empty)         -        -
# 2012-05-31 01:09:29.142869  ...          -  (empty)         -        -
# 2012-05-31 01:09:29.602005  ...          -  (empty)         -        -
#
#                            proxied orig_fuids orig_mime_types  \
# ts
# 2012-05-31 01:09:27.177343       -          -               -
# 2012-05-31 01:09:28.343725       -          -               -
# 2012-05-31 01:09:29.124170       -          -               -
# 2012-05-31 01:09:29.142869       -          -               -
# 2012-05-31 01:09:29.602005       -          -               -
#
#                                     resp_fuids resp_mime_types sample
# ts
# 2012-05-31 01:09:27.177343   FmrItE3tE6uWAdmZV       text/html    NaN
# 2012-05-31 01:09:28.343725  FyKJaS1eo05A7BfpRj      text/plain    NaN
# 2012-05-31 01:09:29.124170  FzLBH53sLcK6bEiRai       text/html    NaN
# 2012-05-31 01:09:29.142869  F6UaIl1po975GOkGJh      text/plain    NaN
# 2012-05-31 01:09:29.602005  FjxdXz2z8deZMyEdvb      image/jpeg    NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Graphing time series data

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = (16.0, 5.0)
df = http_df[6]
df.plot()
df.head

# request_body_len means Actual uncompressed content size of the data transferred from the client
# response_body_len means Actual uncompressed content size of the data transferred from the server  
# code provided by https://github.com/sooshie/Security-Data-Analysis/blob/master/Lab_2/Lab_2-Solutions.ipynb
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-02293c3b49e6> in <module>
#       4 plt.rcParams['figure.figsize'] = (16.0, 5.0)
#       5 df = http_df[6][0:]
# ----> 6 df.plot()
#       7 df.head
#       8
#
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     256     def generate(self):
#     257         self._args_adjust()
# --> 258         self._compute_plot_data()
#     259         self._setup_subplots()
#     260         self._make_plot()
#
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     371         if is_empty:
#     372             raise TypeError('Empty {0!r}: no numeric data to '
# --> 373                             'plot'.format(numeric_data.__class__.__name__))
#     374
#     375         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %% [markdown]
# The figure above shows the actual umcompressed content size of data from the client and server at the end of month. You can see that blue line is very tiny which means comparing to response, it has very small amount of data size transferred.

# %% [markdown]
# ## Resamping data

# %%
# %matplotlib notebook
resamp = df.resample("M", how=['mean', 'count', 'sum']) #"M" means month end frequency
resamp.plot(subplots=True)
# code provided by https://github.com/sooshie/Security-Data-Analysis/blob/master/Lab_2/Lab_2-Solutions.ipynb
# Out:
# C:\Users\seeml\Miniconda3\envs\myenv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
# <img src="data:image/png;base64,..." width="1600">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000029235857FD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002923589E898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000292358C6BE0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000292358F4080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002923591B4E0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000292365C3940>],
#       dtype=object)

# %% [markdown]
# The graph shows that the data that resampled by mean, number of count, total data size at the end of month

# %%
resamp.plot()
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %% [markdown]
# Times Series Model-- ARMA(p,q)
# https://en.wikipedia.org/wiki/Autoregressive–moving-average_model#ARMA_model
#
# using ACF and PACF to determine p and q.
# https://onlinecourses.science.psu.edu/stat510/node/62/
#
# ACF and PACF
# https://machinelearningmastery.com/gentle-introduction-autocorrelation-partial-autocorrelation/
#
# Python code for time series
# https://machinelearningmastery.com/time-series-forecasting-methods-in-python-cheat-sheet/

# %% [markdown]
# ## Try modelling the sum of response_body_len

# %% [markdown]
# ARMA model is combined by two models which are Autoregressive Model(AR) and Moving Average Model(MA)
# To determine the order of the model, i.e ARMA(p,q), p and q are the orders of the model, we need to plot the autocorrelation function plot(acf) to determine q, and partial autocorrelation function(pacf) plot to get p's value.

# %% [markdown]
# Since the big value of data, we need to logarithm our data.

# %%
resamp['response_sum_log']=resamp['response_body_len']['sum'].apply(np.log)

# %%
from statsmodels.tsa.stattools import acf, pacf
#Plot PACF:
lag_pacf = pacf(resamp['response_count_log'], nlags=34, method='ols')
lag_acf = acf(resamp['response_sum_log'], nlags=20)
#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(resamp['response_sum_log'])),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(resamp['response_sum_log'])),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

#Plot PACF:
lag_pacf = pacf(resamp['response_sum_log'], nlags=34, method='ols')
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(resamp['response_sum_log'])),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(resamp['response_sum_log'])),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
# %matplotlib notebook

# autocorrelation plot (acf)
from pandas.tools.plotting import autocorrelation_plot
autocorrelation_plot(resamp['request_log'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'request_log'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-6aa95dc95ce8> in <module>
#       2 # autocorrelation plot (acf)
#       3 from pandas.tools.plotting import autocorrelation_plot
# ----> 4 autocorrelation_plot(resamp['request_log'])
#
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2684             return self._getitem_frame(key)
#    2685         elif is_mi_columns:
# -> 2686             return self._getitem_multilevel(key)
#    2687         else:
#    2688             return self._getitem_column(key)
#
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\core\frame.py in _getitem_multilevel(self, key)
#    2728
#    2729     def _getitem_multilevel(self, key):
# -> 2730         loc = self.columns.get_loc(key)
#    2731         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    2732             new_columns = self.columns[loc]
#
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2235
#    2236         if not isinstance(key, tuple):
# -> 2237             loc = self._get_level_indexer(key, level=0)
#    2238
#    2239             # _get_level_indexer returns an empty slice if the key has
#
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    2494         else:
#    2495
# -> 2496             loc = level_index.get_loc(key)
#    2497             if isinstance(loc, slice):
#    2498                 return loc
#
# ~\Miniconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'request_log'

# %% [markdown]
# By the acf plot, we can get q's value. Q's value depends on how many lags that are beyond the boundaries.
# According to this plot, we can get that lag 1 and maybe lag 2 are above the boundaries, so we can say that q is equal to 1 or 2. We will modelling the data for each q, and compare the Residual Mean Error Square(rmse) of each model.

# %%
# pacf partial autocorrelation func
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(resamp['request_count_log'])

# %% [markdown]
# Similarly, we can use pacf to determine the p value by the same way.
#
# Unfortunatly, there are too many values that are larger than 1 or less than -1, i don't think it is ar model.
#
# Therefore we could say that it is a MA model with q=1 or 2

# %% [markdown]
# ## Fit model and predict

# %% [markdown]
# ### Set Train and Test data
#
# we have 37 months of data, we set first 34 months as training data, and last 3 months as test data.

# %%
#train data
train = resamp['response_body_len']['sum'][0:34]
test = resamp['response_body_len']['sum'][34:37]

# %%
# MA 
from statsmodels.tsa.arima_model import ARMA
# fit model q=2
model = ARMA(train, order=(0, 2))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict(len(train),(len(resamp)-1))
print(yhat)
#Residual MSE
import math
from sklearn.metrics import mean_squared_error
rms = math.sqrt(mean_squared_error(test, yhat))
print(rms)

# %%
# fit model q=1
model = ARMA(train, order=(0, 1))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict(len(train),(len(resamp)-1))
print(yhat)
#Residual MSE
import math
from sklearn.metrics import mean_squared_error
rms = math.sqrt(mean_squared_error(test, yhat))
print(rms)

# %% [markdown]
# comparing two rms, we can get that if q = 1, rmse is smaller. so we choose q = 1

# %% [markdown]
# ## MA(1)
# ![Opera%20Snapshot_2018-10-25_142254_onlinecourses.science.psu.edu.png](attachment:Opera%20Snapshot_2018-10-25_142254_onlinecourses.science.psu.edu.png)
# ![aa.png](attachment:aa.png)
# ![bb.png](attachment:bb.png)

# %% [markdown]
# ## Predict the next month data size

# %%
y_hat = model_fit.predict(len(train),len(resamp))
print(y_hat)

# %% [markdown]
# ## from modelling to the end, the code fails. the output is not i want. for example, for MA(1) model, the predict value for next several months are the same values.
